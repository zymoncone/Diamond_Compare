# %%
# james_allen
JA = [{'carat':3.04,'color':'E','clarity':'VS2','price':9700},
      {'carat':3.05,'color':'E','clarity':'VS2','price':9730},
      {'carat':3.00,'color':'E','clarity':'VS1','price':10960},
      {'carat':3.56,'color':'E','clarity':'VS2','price':11010},
      {'carat':3.14,'color':'E','clarity':'VS1','price':11080},
      {'carat':3.15,'color':'E','clarity':'VVS2','price':12220},
      {'carat':4.02,'color':'E','clarity':'VS2','price':13880},
      {'carat':3.02,'color':'E','clarity':'VS1','price':10660},
      {'carat':3.15,'color':'E','clarity':'VVS2','price':11980},
      {'carat':3.27,'color':'E','clarity':'VVS2','price':12140},
      {'carat':3.56,'color':'E','clarity':'VS2','price':11010},
      {'carat':3.83,'color':'E','clarity':'VS1','price':13780},
      {'carat':4.40,'color':'E','clarity':'VS1','price':17490}]

BE = [{'carat':3.01,'color':'E','clarity':'VS2','price':8770,'cut':'ideal'},
      {'carat':3.02,'color':'E','clarity':'VS2','price':8800,'cut':'super ideal'},
      {'carat':3.01,'color':'E','clarity':'VS2','price':8830,'cut':'super ideal'},
      {'carat':3.07,'color':'E','clarity':'VS2','price':9010,'cut':'super ideal'},
      {'carat':3.13,'color':'E','clarity':'VS2','price':9120,'cut':'ideal'},
      {'carat':3.23,'color':'E','clarity':'VS2','price':9410,'cut':'ideal'},
      {'carat':3.44,'color':'E','clarity':'VS2','price':10020,'cut':'ideal'},
      {'carat':3.00,'color':'D','clarity':'VS2','price':9270,'cut':'ideal'}]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
JA_df = pd.DataFrame(JA)
JA_df['$/carat'] = np.round(JA_df['price'] / JA_df['carat'], 2)
JA_df
# Out:
#    carat color clarity  price  $/carat
# 0   3.04     E     VS2   9700  3190.79
# 1   3.05     E     VS2   9730  3190.16
# 2   3.00     E     VS1  10960  3653.33
# 3   3.56     E     VS2  11010  3092.70
# 4   3.14     E     VS1  11470  3652.87
# 5   3.15     E    VVS2  12220  3879.37
# 6   4.02     E     VS2  13880  3452.74

# %%
sns.scatterplot(data=JA_df, x="price", y="carat", hue="clarity")
plt.show()

# %%
sns.scatterplot(data=JA_df, x="$/carat", y="carat", hue="clarity")
plt.show()
